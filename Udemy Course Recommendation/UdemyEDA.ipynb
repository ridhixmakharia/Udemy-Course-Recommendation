# %%
# Load EDA Pkgs
import pandas as pd
import numpy as np

# %%
# Load Data Viz Pkgs
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
# Hide All Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Load Dataset
df = pd.read_csv("udemy_courses.csv")
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  Business Finance
# 1              39.0  2017-03-09T16:34:20Z  Business Finance
# 2               2.5  2016-12-19T19:26:30Z  Business Finance
# 3               3.0  2017-05-30T20:07:24Z  Business Finance
# 4               2.0  2016-12-13T14:57:18Z  Business Finance

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# How many subject/category are there in the dataset
df['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
# How many subject/category are there in the dataset
len(df['subject'].unique())
# Out:
# 4

# %%
# Distribution of Subject/Value Counts
df['subject'].value_counts()
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
# Plot Distribution of Subject/Value Counts
df['subject'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Plot Distribution of Subject/Value Counts with Pie Chart
plt.figure(figsize=(10,5))
df['subject'].value_counts().plot(kind='pie')
plt.show()

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  Business Finance
# 1              39.0  2017-03-09T16:34:20Z  Business Finance
# 2               2.5  2016-12-19T19:26:30Z  Business Finance
# 3               3.0  2017-05-30T20:07:24Z  Business Finance
# 4               2.0  2016-12-13T14:57:18Z  Business Finance

# %%
# Number of Courses per Subject
df['subject'].value_counts()
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
# Number of subscribers per Subject
df.groupby('subject')['num_subscribers'].sum()
# Out:
# subject
# Business Finance       1868711
# Graphic Design         1063148
# Musical Instruments     846689
# Web Development        7980572
# Name: num_subscribers, dtype: int64

# %%
# Plot of the Number of subscribers per Subject
df.groupby('subject')['num_subscribers'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='subject'>

# %%
# Plot of the Number of subscribers per Subject
df.groupby('subject')['num_subscribers'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='num_subscribers'>

# %%
# Total Number of Subscribers
df['num_subscribers'].sum()
# Out:
# 11759120

# %%
##Average number of subscribers
df['num_subscribers'].mean()
# Out:
# 3197.150625339859

# %%
# Min number of subscriber
df['num_subscribers'].min()
# Out:
# 0

# %%
# Max number of subscriber
df['num_subscribers'].max()
# Out:
# 268923

# %%
# Which course has the highest number of sub
df['num_subscribers'].idxmax()
# Out:
# 2827

# %%
# Get the location
df.iloc[2832]
# Out:
# course_id                                                         984072
# course_title           Build Modern Websites Quick With HTML,CSS and ...
# url                    https://www.udemy.com/build-modern-websites-qu...
# is_paid                                                             True
# price                                                                 20
# num_subscribers                                                      912
# num_reviews                                                           17
# num_lectures                                                          48
# level                                                     Beginner Level
# content_duration                                                     4.5
# published_timestamp                                 2016-10-18T15:48:43Z
# subject                                                  Web Development
# Name: 2832, dtype: object

# %%
# How many levels do we have
df['level'].unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
# What is the distribution of courses per levels
df['level'].value_counts()
# Out:
# All Levels            1929
# Beginner Level        1270
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
# What is the distribution of courses per levels
df['level'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# What is the distribution of courses per levels
df['level'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='level'>

# %%
#  How many subscribers per levels
df.groupby('level')['num_subscribers'].sum()
# Out:
# level
# All Levels            6915076
# Beginner Level        4051843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
df[['num_subscribers','level']]
# Out:
#       num_subscribers               level
# 0                2147          All Levels
# 1                2792          All Levels
# 2                2174  Intermediate Level
# 3                2451          All Levels
# 4                1276  Intermediate Level
# ...               ...                 ...
# 3673             1040          All Levels
# 3674              306      Beginner Level
# 3675              513          All Levels
# 3676              300          All Levels
# 3677              901      Beginner Level
#
# [3678 rows x 2 columns]

# %%
# Plot of How many subscribers per levels
df.groupby('level')['num_subscribers'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='level'>

# %%
#  How many subscribers per levels
df.groupby('level')['num_subscribers'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='num_subscribers'>

# %%
# How many levels per subject category
df.groupby('subject')['level'].value_counts()
# Out:
# subject              level
# Business Finance     All Levels            696
#                      Beginner Level        340
#                      Intermediate Level    128
#                      Expert Level           31
# Graphic Design       All Levels            298
#                      Beginner Level        243
#                      Intermediate Level     57
#                      Expert Level            5
# Musical Instruments  Beginner Level        296
#                      All Levels            276
#                      Intermediate Level    101
#                      Expert Level            7
# Web Development      All Levels            659
#                      Beginner Level        391
#                      Intermediate Level    135
#                      Expert Level           15
# Name: level, dtype: int64

# %%
# Plot of How many levels per subject category
df.groupby('subject')['level'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='subject,level'>

# %%
# Using Seaborn
plt.figure(figsize=(20,10))
sns.barplot(x='level',y='num_subscribers', hue='subject',data=df)
plt.show()

# %%
# Using Seaborn
plt.figure(figsize=(20,10))
sns.barplot(x='level',y='num_subscribers', hue='subject',data=df,ci=None)
plt.show()

# %%
# Using Seaborn
plt.figure(figsize=(20,10))
sns.barplot(x='level',y='num_lectures', hue='subject',data=df,ci=None)
plt.show()

# %%
# EDA on Lectures
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  Business Finance
# 1              39.0  2017-03-09T16:34:20Z  Business Finance
# 2               2.5  2016-12-19T19:26:30Z  Business Finance
# 3               3.0  2017-05-30T20:07:24Z  Business Finance
# 4               2.0  2016-12-13T14:57:18Z  Business Finance

# %%
def plot_num_of_countable_feature(feature):
    # Using Seaborn
    plt.figure(figsize=(10,7))
    plt.title("Plot of {} per level per subject".format(feature))
    sns.barplot(x='level',y=feature, hue='subject',data=df,ci=None)
    plt.show()
    plt.figure(figsize=(10,7))
    #  How many subscribers per levels
    plt.title("Plot of {} per level".format(feature))
    df.groupby('level')[feature].sum().plot(kind='pie')
    plt.show()

# %%
# Plot For the lectures * reviews
plot_num_of_countable_feature('num_reviews')

# %%
# Plot of lectures
plot_num_of_countable_feature('num_lectures')

# %%
# Datatype
df['price'].dtype
# Out:
# dtype('int64')

# %%
# unique price
df.price.unique()
# Out:
# array([200,  75,  45,  95, 150,  65, 195,  30,  20,  50, 175, 140, 115,
#        190, 125,  60, 145, 105, 155, 185, 180, 120,  25, 160,  40,   0,
#        100,  90,  35,  80,  70,  55, 165, 130,  85, 170, 110, 135])

# %%
df['price'] = df['price'].astype(str)
df['price'] = df['price'].str.replace('Free|TRUE', '0')

# %%
df['price'] = df['price'].astype(float)

# %%
# What is the average price
df['price'].mean()
# Out:
# 66.0494834148994

# %%
# What is the max price
df['price'].max()
# Out:
# 200.0

# %%
# What is the max price location
df['price'].idxmax()
# Out:
# 0

# %%
df.iloc[0]
# Out:
# course_id                                                        1070968
# course_title                          Ultimate Investment Banking Course
# url                    https://www.udemy.com/ultimate-investment-bank...
# is_paid                                                             True
# price                                                              200.0
# num_subscribers                                                     2147
# num_reviews                                                           23
# num_lectures                                                          51
# level                                                         All Levels
# content_duration                                                     1.5
# published_timestamp                                 2017-01-18T20:58:58Z
# subject                                                 Business Finance
# Name: 0, dtype: object

# %%
# What is the most profitable course
# price x num_subscriber
df['profit'] = df['price'] * df['num_subscribers']
# What is the most profitable
df['profit'].max()
# Out:
# 24316800.0

# %%
# The location of course
df['profit'].idxmax()
# Out:
# 3230

# %%
df.iloc[3230]
# Out:
# course_id                                                         625204
# course_title                                  The Web Developer Bootcamp
# url                    https://www.udemy.com/the-web-developer-bootcamp/
# is_paid                                                             True
# price                                                              200.0
# num_subscribers                                                   121584
# num_reviews                                                        27445
# num_lectures                                                         342
# level                                                         All Levels
# content_duration                                                    43.0
# published_timestamp                                 2015-11-02T21:13:27Z
# subject                                                  Web Development
# profit                                                        24316800.0
# Name: 3230, dtype: object

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True  200.0
# 1      https://www.udemy.com/goods-and-services-tax/     True   75.0
# 2  https://www.udemy.com/financial-modeling-for-b...     True   45.0
# 3  https://www.udemy.com/complete-excel-finance-c...     True   95.0
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True  200.0
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject    profit
# 0               1.5  2017-01-18T20:58:58Z  Business Finance  429400.0
# 1              39.0  2017-03-09T16:34:20Z  Business Finance  209400.0
# 2               2.5  2016-12-19T19:26:30Z  Business Finance   97830.0
# 3               3.0  2017-05-30T20:07:24Z  Business Finance  232845.0
# 4               2.0  2016-12-13T14:57:18Z  Business Finance  255200.0

# %%
### How Many Courses on Udemy Are paid or free
df['is_paid'].unique()
# Out:
# array([ True, False])

# %%
### How Many Courses on Udemy Are paid or free
df['is_paid'].value_counts()
# Out:
# True     3368
# False     310
# Name: is_paid, dtype: int64

# %%
### How Many Courses on Udemy Are paid or free
df['is_paid'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.countplot(df['is_paid'])
# Out:
# <Axes: ylabel='count'>

# %%
# How many paid/free course in each subject category
df.groupby('is_paid')['subject'].value_counts()
# Out:
# is_paid  subject
# False    Web Development         133
#          Business Finance         96
#          Musical Instruments      46
#          Graphic Design           35
# True     Business Finance       1099
#          Web Development        1067
#          Musical Instruments     634
#          Graphic Design          568
# Name: subject, dtype: int64

# %%
# How many paid/free course in each subject category
df.groupby('is_paid')['subject'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='is_paid,subject'>

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='level',y='is_paid', hue='subject',data=df,ci=None)
plt.show()

# %%
sns.scatterplot(data=df,x='price',y='num_subscribers')
# Out:
# <Axes: xlabel='price', ylabel='num_subscribers'>

# %%
sns.scatterplot(data=df,x='price',y='num_reviews')
# Out:
# <Axes: xlabel='price', ylabel='num_reviews'>

# %%
plt.figure(figsize=(20,10))
plt.title("Does Price Influence Subscription Per Subject Category")
sns.lineplot(data=df,x='price',y='num_subscribers',hue='subject')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.title("Does Reviews Influence Subscription Per Subject Category")
sns.lineplot(data=df,x='num_reviews',y='num_subscribers',hue='subject')
plt.show()

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True  200.0
# 1      https://www.udemy.com/goods-and-services-tax/     True   75.0
# 2  https://www.udemy.com/financial-modeling-for-b...     True   45.0
# 3  https://www.udemy.com/complete-excel-finance-c...     True   95.0
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True  200.0
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject    profit
# 0               1.5  2017-01-18T20:58:58Z  Business Finance  429400.0
# 1              39.0  2017-03-09T16:34:20Z  Business Finance  209400.0
# 2               2.5  2016-12-19T19:26:30Z  Business Finance   97830.0
# 3               3.0  2017-05-30T20:07:24Z  Business Finance  232845.0
# 4               2.0  2016-12-13T14:57:18Z  Business Finance  255200.0

# %%
df['published_timestamp'].dtype
# Out:
# dtype('O')

# %%
df['published_timestamp'].head()
# Out:
# 0    2017-01-18T20:58:58Z
# 1    2017-03-09T16:34:20Z
# 2    2016-12-19T19:26:30Z
# 3    2017-05-30T20:07:24Z
# 4    2016-12-13T14:57:18Z
# Name: published_timestamp, dtype: object

# %%
df['published_timestamp'].str.split('T')
# Out:
# 0       [2017-01-18, 20:58:58Z]
# 1       [2017-03-09, 16:34:20Z]
# 2       [2016-12-19, 19:26:30Z]
# 3       [2017-05-30, 20:07:24Z]
# 4       [2016-12-13, 14:57:18Z]
#                  ...
# 3673    [2016-06-14, 17:36:46Z]
# 3674    [2017-03-10, 22:24:30Z]
# 3675    [2015-12-30, 16:41:42Z]
# 3676    [2016-08-11, 19:06:15Z]
# 3677    [2014-09-28, 19:51:11Z]
# Name: published_timestamp, Length: 3678, dtype: object

# %%
df['published_date'] = df['published_timestamp'].str.split('T').str.get(0)

# %%
df['published_date']
# Out:
# 0       2017-01-18
# 1       2017-03-09
# 2       2016-12-19
# 3       2017-05-30
# 4       2016-12-13
#            ...
# 3673    2016-06-14
# 3674    2017-03-10
# 3675    2015-12-30
# 3676    2016-08-11
# 3677    2014-09-28
# Name: published_date, Length: 3678, dtype: object

# %%
from datetime import datetime
def convert_to_dt(x):
    mydate = datetime.strptime(x,'%Y-%m-%d')
    result = mydate.strftime("%Y-%m-%d")
    return result

# %%
df['published_date'] = df['published_date'].str.replace('3 hours','2017-01-18')
convert_to_dt("2017-01-18")
# Out:
# '2017-01-18'

# %%
df['published_date'].apply(lambda x: convert_to_dt(x))
# Out:
# 0       2017-01-18
# 1       2017-03-09
# 2       2016-12-19
# 3       2017-05-30
# 4       2016-12-13
#            ...
# 3673    2016-06-14
# 3674    2017-03-10
# 3675    2015-12-30
# 3676    2016-08-11
# 3677    2014-09-28
# Name: published_date, Length: 3678, dtype: object

# %%
df['published_date'] = df['published_date'].apply(lambda x: convert_to_dt(x))
df.dtypes
# Out:
# course_id                int64
# course_title            object
# url                     object
# is_paid                   bool
# price                  float64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# profit                 float64
# published_date          object
# dtype: object

# %%
df['published_date'] = pd.to_datetime(df['published_date'],format="%Y-%m-%d")
df.dtypes
# Out:
# course_id                       int64
# course_title                   object
# url                            object
# is_paid                          bool
# price                         float64
# num_subscribers                 int64
# num_reviews                     int64
# num_lectures                    int64
# level                          object
# content_duration              float64
# published_timestamp            object
# subject                        object
# profit                        float64
# published_date         datetime64[ns]
# dtype: object

# %%
df['year'] = df['published_date'].dt.year
df['month'] = df['published_date'].dt.month
df['day'] = df['published_date'].dt.day
df.groupby('year')['num_subscribers'].value_counts()
# Out:
# year  num_subscribers
# 2011  3697               1
#       7014               1
#       12458              1
#       26673              1
#       69186              1
#                         ..
# 2017  15276              1
#       16158              1
#       16829              1
#       17784              1
#       26742              1
# Name: num_subscribers, Length: 2893, dtype: int64

# %%
# Plot of Sub Per Year
df.groupby('year')['num_subscribers'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='year,num_subscribers'>

# %%
plt.figure(figsize=(20,10))
plt.title("Plot of Subscription Per Year Per Subject Category")
sns.lineplot(data=df,x='year',y='num_subscribers',hue='subject')
plt.show()

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True  200.0
# 1      https://www.udemy.com/goods-and-services-tax/     True   75.0
# 2  https://www.udemy.com/financial-modeling-for-b...     True   45.0
# 3  https://www.udemy.com/complete-excel-finance-c...     True   95.0
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True  200.0
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject    profit  \
# 0               1.5  2017-01-18T20:58:58Z  Business Finance  429400.0
# 1              39.0  2017-03-09T16:34:20Z  Business Finance  209400.0
# 2               2.5  2016-12-19T19:26:30Z  Business Finance   97830.0
# 3               3.0  2017-05-30T20:07:24Z  Business Finance  232845.0
# 4               2.0  2016-12-13T14:57:18Z  Business Finance  255200.0
#
#   published_date  year  month  day
# 0     2017-01-18  2017      1   18
# 1     2017-03-09  2017      3    9
# 2     2016-12-19  2016     12   19
# 3     2017-05-30  2017      5   30
# 4     2016-12-13  2016     12   13

# %%
# Get the Longest Title for a course
df['course_title'].str.len()
# Out:
# 0       34
# 1       59
# 2       56
# 3       50
# 4       44
#         ..
# 3673    56
# 3674    55
# 3675    29
# 3676    54
# 3677    52
# Name: course_title, Length: 3678, dtype: int64

# %%
# Get the Longest Title for a course
df['course_title_len'] = df['course_title'].str.len()
# Get Longest title
df['course_title_len'].max()
# Out:
# 243

# %%
# Get tlocation
df.iloc[243]
# Out:
# course_id                                                         337320
# course_title           Cash Flow Valuation: Develop Your Financial Li...
# url                     https://www.udemy.com/financial-literacy-basics/
# is_paid                                                             True
# price                                                              105.0
# num_subscribers                                                     2987
# num_reviews                                                           23
# num_lectures                                                          19
# level                                                         All Levels
# content_duration                                                     2.0
# published_timestamp                                 2014-12-22T13:39:16Z
# subject                                                 Business Finance
# profit                                                          313635.0
# published_date                                       2014-12-22 00:00:00
# year                                                                2014
# month                                                                 12
# day                                                                   22
# course_title_len                                                      52
# Name: 243, dtype: object

# %% [markdown]
# # **KEYWORD EXTRACTION**

# %%
df['course_title']
# Out:
# 0                      Ultimate Investment Banking Course
# 1       Complete GST Course & Certification - Grow You...
# 2       Financial Modeling for Business Analysts and C...
# 3       Beginner to Pro - Financial Analysis in Excel ...
# 4            How To Maximize Your Profits Trading Options
#                               ...
# 3673    Learn jQuery from Scratch - Master of JavaScri...
# 3674    How To Design A WordPress Website With No Codi...
# 3675                        Learn and Build using Polymer
# 3676    CSS Animations: Create Amazing Effects on Your...
# 3677    Using MODX CMS to Build Websites: A Beginner's...
# Name: course_title, Length: 3678, dtype: object

# %%
# !pip install neattext
# Out:
# Collecting neattext
#   Downloading neattext-0.1.3-py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.7/114.7 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: neattext
# Successfully installed neattext-0.1.3

# %%
# Text Cleaning to remove stopwords
import neattext.functions as nfx

# %%
dir(nfx)
# Out:
# ['BTC_ADDRESS_REGEX',
#  'CURRENCY_REGEX',
#  'CURRENCY_SYMB_REGEX',
#  'Counter',
#  'DATE_REGEX',
#  'EMAIL_REGEX',
#  'EMOJI_REGEX',
#  'HASTAG_REGEX',
#  'MASTERCard_REGEX',
#  'MD5_SHA_REGEX',
#  'MOST_COMMON_PUNCT_REGEX',
#  'NUMBERS_REGEX',
#  'PHONE_REGEX',
#  'PoBOX_REGEX',
#  'SPECIAL_CHARACTERS_REGEX',
#  'STOPWORDS',
#  'STOPWORDS_de',
#  'STOPWORDS_en',
#  'STOPWORDS_es',
#  'STOPWORDS_fr',
#  'STOPWORDS_ru',
#  'STOPWORDS_yo',
#  'STREET_ADDRESS_REGEX',
#  'TextFrame',
#  'URL_PATTERN',
#  'USER_HANDLES_REGEX',
#  'VISACard_REGEX',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__generate_text',
#  '__loader__',
#  '__name__',
#  '__numbers_dict',
#  '__package__',
#  '__spec__',
#  '_lex_richness_herdan',
#  '_lex_richness_maas_ttr',
#  'clean_text',
#  'defaultdict',
#  'digit2words',
#  'extract_btc_address',
#  'extract_currencies',
#  'extract_currency_symbols',
#  'extract_dates',
#  'extract_emails',
#  'extract_emojis',
#  'extract_hashtags',
#  'extract_html_tags',
#  'extract_mastercard_addr',
#  'extract_md5sha',
#  'extract_numbers',
#  'extract_pattern',
#  'extract_phone_numbers',
#  'extract_postoffice_box',
#  'extract_shortwords',
#  'extract_special_characters',
#  'extract_stopwords',
#  'extract_street_address',
#  'extract_terms_in_bracket',
#  'extract_urls',
#  'extract_userhandles',
#  'extract_visacard_addr',
#  'fix_contractions',
#  'generate_sentence',
#  'hamming_distance',
#  'inverse_df',
#  'lexical_richness',
#  'markov_chain',
#  'math',
#  'nlargest',
#  'normalize',
#  'num2words',
#  'random',
#  're',
#  'read_txt',
#  'remove_accents',
#  'remove_bad_quotes',
#  'remove_btc_address',
#  'remove_currencies',
#  'remove_currency_symbols',
#  'remove_custom_pattern',
#  'remove_custom_words',
#  'remove_dates',
#  'remove_emails',
#  'remove_emojis',
#  'remove_hashtags',
#  'remove_html_tags',
#  'remove_mastercard_addr',
#  'remove_md5sha',
#  'remove_multiple_spaces',
#  'remove_non_ascii',
#  'remove_numbers',
#  'remove_phone_numbers',
#  'remove_postoffice_box',
#  'remove_puncts',
#  'remove_punctuations',
#  'remove_shortwords',
#  'remove_special_characters',
#  'remove_stopwords',
#  'remove_street_address',
#  'remove_terms_in_bracket',
#  'remove_urls',
#  'remove_userhandles',
#  'remove_visacard_addr',
#  'replace_bad_quotes',
#  'replace_currencies',
#  'replace_currency_symbols',
#  'replace_dates',
#  'replace_emails',
#  'replace_emojis',
#  'replace_numbers',
#  'replace_phone_numbers',
#  'replace_special_characters',
#  'replace_term',
#  'replace_urls',
#  'string',
#  'term_freq',
#  'to_txt',
#  'unicodedata',
#  'word_freq',
#  'word_length_freq']

# %%
df['clean_title'] = df['course_title'].apply(nfx.remove_stopwords)
df[['clean_title','course_title']]
# Out:
#                                             clean_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow Pra...
# 2      Financial Modeling Business Analysts Consultants
# 3          Beginner Pro - Financial Analysis Excel 2017
# 4                      Maximize Profits Trading Options
# ...                                                 ...
# 3673   Learn jQuery Scratch - Master JavaScript library
# 3674                    Design WordPress Website Coding
# 3675                                Learn Build Polymer
# 3676     CSS Animations: Create Amazing Effects Website
# 3677          MODX CMS Build Websites: Beginner's Guide
#
#                                            course_title
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 3673  Learn jQuery from Scratch - Master of JavaScri...
# 3674  How To Design A WordPress Website With No Codi...
# 3675                      Learn and Build using Polymer
# 3676  CSS Animations: Create Amazing Effects on Your...
# 3677  Using MODX CMS to Build Websites: A Beginner's...
#
# [3678 rows x 2 columns]

# %%
df['clean_title'] = df['clean_title'].apply(nfx.remove_special_characters)
df['clean_title']
# Out:
# 0                      Ultimate Investment Banking Course
# 1       Complete GST Course  Certification  Grow Practice
# 2        Financial Modeling Business Analysts Consultants
# 3             Beginner Pro  Financial Analysis Excel 2017
# 4                        Maximize Profits Trading Options
#                               ...
# 3673      Learn jQuery Scratch  Master JavaScript library
# 3674                      Design WordPress Website Coding
# 3675                                  Learn Build Polymer
# 3676        CSS Animations Create Amazing Effects Website
# 3677              MODX CMS Build Websites Beginners Guide
# Name: clean_title, Length: 3678, dtype: object

# %%
# Tokenization
all_title_list = df['clean_title'].to_list()
all_title_list[1:10]
# Out:
# ['Complete GST Course  Certification  Grow Practice',
#  'Financial Modeling Business Analysts Consultants',
#  'Beginner Pro  Financial Analysis Excel 2017',
#  'Maximize Profits Trading Options',
#  'Trading Penny Stocks Guide Levels 2017',
#  'Investing Trading Beginners Mastering Price Charts',
#  'Trading Stock Chart Patterns Immediate Explosive Gains',
#  'Options Trading 3  Advanced Stock Profit Success Method',
#  'Investment Strategy Need Retirement']

# %%
for line in all_title_list[1:5]:
    print(line.split())
    for i in line.split():
        print(i)
# Out:
# ['Complete', 'GST', 'Course', 'Certification', 'Grow', 'Practice']
# Complete
# GST
# Course
# Certification
# Grow
# Practice
# ['Financial', 'Modeling', 'Business', 'Analysts', 'Consultants']
# Financial
# Modeling
# Business
# Analysts
# Consultants
# ['Beginner', 'Pro', 'Financial', 'Analysis', 'Excel', '2017']
# Beginner
# Pro
# Financial
# Analysis
# Excel
# 2017
# ['Maximize', 'Profits', 'Trading', 'Options']
# Maximize
# Profits
# Trading
# Options

# %%
all_tokens = [i for line in all_title_list for i in line.split()]
all_tokens
# Out:
# ['Ultimate',
#  'Investment',
#  'Banking',
#  'Course',
#  'Complete',
#  'GST',
#  'Course',
#  'Certification',
#  'Grow',
#  'Practice',
#  'Financial',
#  'Modeling',
#  'Business',
#  'Analysts',
#  'Consultants',
#  'Beginner',
#  'Pro',
#  'Financial',
#  'Analysis',
#  'Excel',
#  '2017',
#  'Maximize',
#  'Profits',
#  'Trading',
#  'Options',
#  'Trading',
#  'Penny',
#  'Stocks',
#  'Guide',
#  'Levels',
#  '2017',
#  'Investing',
#  'Trading',
#  'Beginners',
#  'Mastering',
#  'Price',
#  'Charts',
#  'Trading',
#  'Stock',
#  'Chart',
#  'Patterns',
#  'Immediate',
#  'Explosive',
#  'Gains',
#  'Options',
#  'Trading',
#  '3',
#  'Advanced',
#  'Stock',
#  'Profit',
#  'Success',
#  'Method',
#  'Investment',
#  'Strategy',
#  'Need',
#  'Retirement',
#  'Forex',
#  'Trading',
#  'Secrets',
#  'Pros',
#  'Amazons',
#  'AWS',
#  'Trading',
#  'Options',
#  'Money',
#  'Flow',
#  'Financial',
#  'Management',
#  'Risk',
#  'Return',
#  'Securities',
#  'Forex',
#  'Trading',
#  'Course',
#  'Work',
#  'Smarter',
#  'Harder',
#  'Proven',
#  'Results',
#  'Python',
#  'Algo',
#  'Trading',
#  'Sentiment',
#  'Trading',
#  'News',
#  'Short',
#  'Selling',
#  'Learn',
#  'Sell',
#  'Stocks',
#  'Fall',
#  'Basic',
#  'Technical',
#  'Analysis',
#  'Learn',
#  'structure',
#  'market',
#  'Complete',
#  'Chart',
#  'Pattern',
#  'Trading',
#  'Course',
#  'Proven',
#  'Approach',
#  '7',
#  'Deadly',
#  'Mistakes',
#  'Investing',
#  'Slash',
#  'Profits',
#  'Financial',
#  'Statements',
#  'Easy',
#  'Winning',
#  'Forex',
#  'Trading',
#  'Live',
#  'Forex',
#  'Trading',
#  'Examples',
#  'Forex',
#  'Traders',
#  'Create',
#  'Trading',
#  'Robot',
#  'Coding',
#  'Create',
#  'Business',
#  'Home',
#  'Trading',
#  'Stocks',
#  'Today',
#  '2017',
#  'Introduction',
#  'Accounting',
#  'Mastering',
#  'Financial',
#  'Statements',
#  'Complete',
#  'Ethereum',
#  'Course',
#  '01',
#  'Ether',
#  'Wallet',
#  'Beginner',
#  'Pro',
#  'PowerPoint',
#  'Complete',
#  'PowerPoint',
#  'Training',
#  'Investing',
#  '101',
#  'Complete',
#  'Online',
#  'Investing',
#  'Course',
#  'Create',
#  'Hedge',
#  'Fund',
#  'Trade',
#  'Stocks',
#  'Like',
#  'Fund',
#  'Manager',
#  'Learn',
#  'MQL5',
#  'Build',
#  '8Currency',
#  'Hedging',
#  'Robot',
#  'MetaTrader',
#  '5',
#  'Forex',
#  'Trading',
#  'Complete',
#  'Guide',
#  'Started',
#  'Like',
#  'Pro',
#  'Python',
#  'Algo',
#  'Stock',
#  'Trading',
#  'Automate',
#  'Trading',
#  'Forex',
#  'Robot',
#  'Incredible',
#  'ROI',
#  'Robot',
#  'Included',
#  'Complete',
#  'Bitcoin',
#  'Course',
#  '001',
#  'Bitcoin',
#  'Wallet',
#  'Mastering',
#  'High',
#  'Probability',
#  'Iron',
#  'Condor',
#  'Options',
#  'Trading',
#  'Complete',
#  'Short',
#  'Course',
#  'Ethereum',
#  'Options',
#  'Trading',
#  'Stocks',
#  'Proven',
#  'Toolbox',
#  'Financial',
#  'Success',
#  'Forex',
#  'Trading',
#  'AZ',
#  'LIVE',
#  'Examples',
#  'Forex',
#  'Trading',
#  'Introduction',
#  'Finance',
#  'Accounting',
#  'Modeling',
#  'Valuation',
#  'Beginner',
#  'Pro',
#  'Excel',
#  'Financial',
#  'Modeling',
#  'Valuation',
#  'Complete',
#  'Investment',
#  'Banking',
#  'Course',
#  '2017',
#  'Complete',
#  'Financial',
#  'Analyst',
#  'Course',
#  '2017',
#  'Python',
#  'Finance',
#  'Investment',
#  'Fundamentals',
#  'Data',
#  'Analytics',
#  'Financial',
#  'Modeling',
#  'Startups',
#  'Small',
#  'Businesses',
#  'Options',
#  'Trading',
#  'Win',
#  'Weekly',
#  'Options',
#  'Black',
#  'Algo',
#  'Trading',
#  'Build',
#  'Trading',
#  'Robot',
#  'Accounting',
#  'Financial',
#  'Statement',
#  'Analysis',
#  'Complete',
#  'Training',
#  'Cryptocurrency',
#  'Trading',
#  'Complete',
#  'Guide',
#  'Trading',
#  'Altcoins',
#  'Forex',
#  'Robots',
#  'Expect',
#  'Earn',
#  '175',
#  'PA',
#  'Forex',
#  'Robot',
#  'Included',
#  'Steps',
#  'Trading',
#  'Live',
#  'Trading',
#  'Real',
#  'Account',
#  'Option',
#  'Trading',
#  'Rookies',
#  'Understand',
#  'Options',
#  'Completely',
#  'Learned',
#  'Stock',
#  'Trading',
#  'and',
#  'Too',
#  'Learn',
#  'Trade',
#  'Profit',
#  'Find',
#  'Trade',
#  'Winning',
#  'Stocks',
#  'Trading',
#  'Inside',
#  'Bars',
#  'Master',
#  '1',
#  'Easy',
#  'Pattern',
#  'Successful',
#  'Fundamentals',
#  'Financial',
#  'Planning',
#  'Options',
#  'Trading',
#  'Calendar',
#  'Spread',
#  'Course',
#  'Trader',
#  'Dividend',
#  'Investing',
#  'Build',
#  'Portfolio',
#  'Better',
#  'Future',
#  'Learn',
#  'Accounting',
#  'Understand',
#  'Business',
#  'Consistently',
#  'Win',
#  'Trading',
#  'Stocks',
#  '30',
#  'Days',
#  'Beginners',
#  'Guide',
#  'Quantopian',
#  'Futures',
#  'API',
#  'Buy',
#  'Cheap',
#  'Options',
#  'Options',
#  'Trading',
#  'Pricing',
#  'Model',
#  'Excel',
#  'Crash',
#  'Course',
#  'Master',
#  'Excel',
#  'Financial',
#  'Analysis',
#  'Comprehensive',
#  'Guide',
#  'Financial',
#  'Markets',
#  'Investing',
#  'Trading',
#  'Stock',
#  'Trading',
#  'Ninja',
#  'Complete',
#  'System',
#  'Trading',
#  'Success',
#  'Hedge',
#  'Mutual',
#  'Fund',
#  'Careers',
#  'Complete',
#  'Guide',
#  'Algorithmic',
#  'Trading',
#  'Forex',
#  'Create',
#  'Forex',
#  'Robot',
#  'Power',
#  'Modeling',
#  'Bootcamp',
#  'Advanced',
#  'Excel',
#  '10',
#  'Days',
#  'Options',
#  'Trading',
#  'Basics',
#  '3Course',
#  'Bundle',
#  'Win',
#  '97',
#  'Options',
#  'Trades',
#  'Consistent',
#  'Returns',
#  'Trading',
#  'Options',
#  'Forex',
#  'Strategies',
#  'Kelly',
#  'Criterion',
#  'Larry',
#  'Williams',
#  'more',
#  'Elite',
#  'Trend',
#  'Trader',
#  'Learn',
#  'Trade',
#  'Stocks',
#  'Options',
#  'Forex',
#  'Options',
#  'Trading',
#  'Introduction',
#  'Day',
#  'Trade',
#  'Stock',
#  'Options',
#  'Perfect',
#  'Options',
#  'Trading',
#  'Strategy',
#  'System',
#  'Unique',
#  'Forex',
#  'Trading',
#  'Learn',
#  'Trade',
#  'Forex',
#  'Like',
#  'Banks',
#  'Learn',
#  'Trade',
#  'ProfitTrading',
#  'Japanese',
#  'Candlesticks',
#  'Powerful',
#  'Options',
#  'Spread',
#  'Trading',
#  'Ratio',
#  'Spread',
#  'Finance',
#  'Job',
#  'You',
#  'Explanation',
#  '14',
#  'Finance',
#  'Roles',
#  'Blueprint',
#  'Successful',
#  'Stock',
#  'Trading',
#  'Trading',
#  'Beginners',
#  'Intermediate',
#  'Level',
#  'Start',
#  'Trading',
#  'Stocks',
#  'Technical',
#  'Analysis',
#  'Learn',
#  'Set',
#  'Incubator',
#  'Hedge',
#  'Fund',
#  'StepbyStep',
#  'VPS',
#  'Forex',
#  'Trading',
#  'Protect',
#  'Forex',
#  'Robots',
#  'Introduction',
#  'Accounting',
#  'Language',
#  'Business',
#  'Basic',
#  'Excel',
#  'Basic',
#  'Bookkeeping',
#  'Accounting',
#  'The',
#  'Greeks',
#  'Understand',
#  'Options',
#  'Trading',
#  'Options',
#  'Consistent',
#  'Returns',
#  'Calendar',
#  'Spreads',
#  'Create',
#  'Personal',
#  'Budget',
#  'Complete',
#  'Value',
#  'Investing',
#  'Course',
#  'Proven',
#  'Approach',
#  'FOREX',
#  'Trading',
#  'Price',
#  'Action',
#  'Emini',
#  'ES',
#  'Futures',
#  'Advanced',
#  'Non',
#  'Directional',
#  'Options',
#  'Trading',
#  'Forex',
#  'Trading',
#  'Advanced',
#  'Fundamental',
#  'Analysis',
#  'Invest',
#  'Tiny',
#  'Capital',
#  'Stocks',
#  'Learn',
#  'Successfully',
#  'Trade',
#  'Stocks',
#  '5',
#  'Simple',
#  'Steps',
#  'Forex',
#  'MetaTrader',
#  '4',
#  'Master',
#  'MT4',
#  'Like',
#  'Pro',
#  'Forex',
#  'Trader',
#  'Intermediate',
#  'Options',
#  'trading',
#  'concepts',
#  'Stocks',
#  'Options',
#  'Options',
#  'Trading',
#  '101',
#  'Basics',
#  'Practical',
#  'Accounts',
#  'APP',
#  'Overview',
#  'Bitcoin',
#  'Profits',
#  'Beginners',
#  'Trend',
#  'Traders',
#  'Club',
#  'Find',
#  'Trade',
#  'Fast',
#  'Moving',
#  'Trends',
#  'Financial',
#  'Statements',
#  'Basics',
#  'High',
#  'performance',
#  'Stock',
#  'Trading',
#  'key',
#  'Options',
#  'techniques',
#  'Introduction',
#  'Financial',
#  'Statement',
#  'Analysis',
#  'Basics',
#  'Economics',
#  'College',
#  'Level',
#  'Stock',
#  'Market',
#  'Investing',
#  'Beginners',
#  'Accounting',
#  'Beginners',
#  'Learn',
#  'Basics',
#  '1',
#  'Hour',
#  'Straddle',
#  'Options',
#  'Trading',
#  'Profit',
#  'Market',
#  'Direction',
#  'Fundamentals',
#  'Forex',
#  'Trading',
#  'Binary',
#  'Options',
#  'Trading',
#  'Strategies',
#  '90',
#  'Accuracy',
#  'Signals',
#  'Website',
#  'Investing',
#  '101',
#  'Buying',
#  'Selling',
#  'Online',
#  'Businesses',
#  'Practical',
#  'Accounts',
#  'Bookkeeping',
#  'Automated',
#  'Overview',
#  'Live',
#  'Account',
#  'ETF',
#  'Trading',
#  'System',
#  'Hacking',
#  'Stock',
#  'Market',
#  'Stock',
#  'Market',
#  'Leverage',
#  'Start',
#  'Trading',
#  'Options',
#  'Wisely',
#  'Stock',
#  'Market',
#  'Foundations',
#  'Crash',
#  'Course',
#  'Working',
#  'Capital',
#  'Management',
#  'Advanced',
#  'Accounting',
#  'Complete',
#  'Study',
#  'CMA',
#  'CFA',
#  'CS',
#  '61',
#  'Profit',
#  '1',
#  'Month',
#  'Crush',
#  'Forex',
#  'Trading',
#  'Paradigm',
#  'create',
#  'routine',
#  'Trading',
#  'Forex',
#  'Trading',
#  'Secrets',
#  'MT4',
#  'Robot',
#  'EA',
#  'inside',
#  'coding',
#  'Forex',
#  'SOS',
#  'Course',
#  'Trading',
#  'Tweaks',
#  'Working',
#  'Forex',
#  'Strategy',
#  'Introduction',
#  'Financial',
#  'Modeling',
#  'Quantitative',
#  'Aptitude',
#  'Banking',
#  'Competitive',
#  'Examinations',
#  'Option',
#  'Spreads',
#  'Credit',
#  'Spreads',
#  'Bundle',
#  'B',
#  'Com',
#  'Accountancy',
#  'Paper',
#  'ECO',
#  '02',
#  'IGNOU',
#  'FOREX',
#  'TRADING',
#  'Learn',
#  'quick',
#  'profitable',
#  'way',
#  'support',
#  'Auditing',
#  'Basics',
#  'Professional',
#  'Course',
#  'Level',
#  'Stock',
#  'market',
#  'Investing',
#  'Encyclopedia',
#  'invest',
#  'stocks',
#  'Learn',
#  'basics',
#  'preparing',
#  'accounting',
#  'statements',
#  'Elliott',
#  'Wave',
#  'Forex',
#  'Trading',
#  'Elliott',
#  'Wave',
#  'Theory',
#  'Corporate',
#  'Finance',
#  'Brief',
#  'Introduction',
#  'Excel',
#  'functions',
#  'analyze',
#  'visualize',
#  'data',
#  'Building',
#  'Financial',
#  'Statements',
#  'Excel',
#  'Transfer',
#  'Pricing',
#  'Complete',
#  'Analysis',
#  'Accounting',
#  'Hired',
#  'Work',
#  'Experience',
#  'Forex',
#  'Trading',
#  'Beginners',
#  'Basics',
#  'Basic',
#  'Bookkeeping',
#  'Hacks',
#  'Complete',
#  'Trading',
#  'Plan',
#  'Course',
#  'Stocks',
#  'Forex',
#  '10',
#  'Hours',
#  'Forex',
#  'Trading',
#  'Fixed',
#  'Risk',
#  'Options',
#  'Trading',
#  'Intro',
#  'Investment',
#  'Banking',
#  'MA',
#  'IPO',
#  'Modeling',
#  'Free',
#  'Book',
#  'Pick',
#  'Right',
#  'Penny',
#  'Stocks',
#  'Invest',
#  '2017',
#  '10',
#  'Trading',
#  'Ideas',
#  'Equities',
#  'Market',
#  'Intro',
#  'Financial',
#  'Modeling',
#  'Shark',
#  'Accounting',
#  'Building',
#  'Business',
#  'Numbers',
#  'Forex',
#  'Trading',
#  'TRADE',
#  'TODAY',
#  'Accounting',
#  '60',
#  'Minutes',
#  'Brief',
#  'Introduction',
#  'SAP',
#  'FICO',
#  'Beginners',
#  'Guide',
#  'SAP',
#  'Financial',
#  'Accounts',
#  'Learn',
#  'double',
#  'Forex',
#  'Trading',
#  'Account',
#  'trade',
#  'Accounting',
#  'Superpowers',
#  'Learn',
#  'Accounts',
#  'Understand',
#  'Business',
#  'Python',
#  'Algo',
#  'Trading',
#  'FX',
#  'Trading',
#  'Oanda',
#  'Save',
#  'Taxes',
#  'Financial',
#  'Model',
#  'Basics',
#  'Build',
#  'model',
#  'start',
#  'finish',
#  'Option',
#  'Trading',
#  'Rookies',
#  'Covered',
#  'Option',
#  'Strategy',
#  'EFT',
#  'Stock',
#  'Options',
#  'Trading',
#  'Success',
#  'Making',
#  'Better',
#  'Trades',
#  'Learn',
#  'Trade',
#  'Stock',
#  'Market',
#  'Blowing',
#  'Profits',
#  'Credit',
#  'Repair',
#  'Publication',
#  'Amazon',
#  'Live',
#  'LIFE',
#  'Fundamentals',
#  'Accounting',
#  'RSI',
#  'Options',
#  'Trading',
#  'Technical',
#  'Analysis',
#  '3',
#  'Course',
#  'Bundle',
#  'Basics',
#  'Mutual',
#  'Funds',
#  'CMA',
#  'CS',
#  'CFA',
#  'Exams',
#  'Accounting',
#  '101',
#  'read',
#  'Accounting',
#  'Balance',
#  'Sheet',
#  'Stock',
#  'Options',
#  'Day',
#  'Trading',
#  'Mindset',
#  'Success',
#  'Introduction',
#  'bookkeeping',
#  'Accounting',
#  'Learn',
#  'Trade',
#  'News',
#  'Value',
#  'Investing',
#  'Taught',
#  'Superinvestors',
#  'Trading',
#  'Independent',
#  'Investor',
#  'Course',
#  'Acquired',
#  'Learn',
#  'Head',
#  'Acquisitions',
#  'eBay',
#  'Stock',
#  'Market',
#  'investment',
#  'Practical',
#  'Accounting',
#  'remove',
#  'Risk',
#  'Penny',
#  'Stocks',
#  'Options',
#  'Trading',
#  'Accounting',
#  'Basics',
#  '66',
#  'Minutes',
#  'absolutely',
#  'beginners',
#  'Tax',
#  'Accounting',
#  'Difficult',
#  'Topic',
#  'Easy',
#  'Understand',
#  'Analysis',
#  'Company',
#  'Financial',
#  'Statements',
#  'Forex',
#  'Trading',
#  'Like',
#  'Banks',
#  'Step',
#  'Step',
#  'Live',
#  'Examples',
#  'Fundamentals',
#  'Investing',
#  'Bank',
#  'Financial',
#  'Management',
#  'Comprehensive',
#  'Study',
#  'Learn',
#  'Trade',
#  'Forex',
#  'Stocks',
#  'Beginner',
#  'Advanced',
#  'Master',
#  'Technical',
#  'Analysis',
#  'Chart',
#  'reading',
#  'skills',
#  'Bundle',
#  'Naked',
#  'Options',
#  'Trade',
#  'Covered',
#  'Poor',
#  'Man',
#  'Covered',
#  'Ultimate',
#  'Guide',
#  'Dividend',
#  'Dividend',
#  'Growth',
#  'Investing',
#  'Charting',
#  'Beginners',
#  '101',
#  'Technical',
#  'Analysis',
#  'Demystified',
#  'Build',
#  'DCF',
#  ...]

# %%
from collections import Counter
word_freq = Counter(all_tokens)
# Top Words
dict(word_freq.most_common(30))
# Out:
# {'Learn': 491,
#  'Trading': 280,
#  'Beginners': 246,
#  'Course': 231,
#  'Guitar': 208,
#  'Web': 205,
#  'Design': 187,
#  'Complete': 181,
#  'Piano': 177,
#  'Photoshop': 166,
#  'Forex': 163,
#  'Build': 161,
#  'Financial': 138,
#  'Create': 135,
#  'JavaScript': 123,
#  'Beginner': 120,
#  'Guide': 116,
#  'HTML': 116,
#  'Accounting': 111,
#  'Website': 110,
#  'Development': 110,
#  '2': 106,
#  'PHP': 105,
#  'Options': 101,
#  'Adobe': 100,
#  'Play': 98,
#  '1': 97,
#  'de': 97,
#  'Introduction': 93,
#  'CSS': 92}

# %%
top_words = dict(word_freq.most_common(50))
plt.figure(figsize=(20,10))
plt.bar(*zip(*top_words.items()))
plt.xticks(rotation=45)
plt.show()

# %%
# !pip install rake-nltk
# Out:
# Collecting rake-nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.10/dist-packages (from rake-nltk) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.66.1)
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.6

# %%
import nltk
from rake_nltk import Rake
nltk.download('stopwords')
nltk.download('punkt')
r = Rake()
join_words = ' '.join(all_tokens)
join_words
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 'Ultimate Investment Banking Course Complete GST Course Certification Grow Practice Financial Modeling Business Analysts Consultants Beginner Pro Financial Analysis Excel 2017 Maximize Profits Trading Options Trading Penny Stocks Guide Levels 2017 Investing Trading Beginners Mastering Price Charts Trading Stock Chart Patterns Immediate Explosive Gains Options Trading 3 Advanced Stock Profit Success Method Investment Strategy Need Retirement Forex Trading Secrets Pros Amazons AWS Trading Options Money Flow Financial Management Risk Return Securities Forex Trading Course Work Smarter Harder Proven Results Python Algo Trading Sentiment Trading News Short Selling Learn Sell Stocks Fall Basic Technical Analysis Learn structure market Complete Chart Pattern Trading Course Proven Approach 7 Deadly Mistakes Investing Slash Profits Financial Statements Easy Winning Forex Trading Live Forex Trading Examples Forex Traders Create Trading Robot Coding Create Business Home Trading Stocks Today 2017 Introduction Accounting Mastering Financial Statements Complete Ethereum Course 01 Ether Wallet Beginner Pro PowerPoint Complete PowerPoint Training Investing 101 Complete Online Investing Course Create Hedge Fund Trade Stocks Like Fund Manager Learn MQL5 Build 8Currency Hedging Robot MetaTrader 5 Forex Trading Complete Guide Started Like Pro Python Algo Stock Trading Automate Trading Forex Robot Incredible ROI Robot Included Complete Bitcoin Course 001 Bitcoin Wallet Mastering High Probability Iron Condor Options Trading Complete Short Course Ethereum Options Trading Stocks Proven Toolbox Financial Success Forex Trading AZ LIVE Examples Forex Trading Introduction Finance Accounting Modeling Valuation Beginner Pro Excel Financial Modeling Valuation Complete Investment Banking Course 2017 Complete Financial Analyst Course 2017 Python Finance Investment Fundamentals Data Analytics Financial Modeling Startups Small Businesses Options Trading Win Weekly Options Black Algo Trading Build Trading Robot Accounting Financial Statement Analysis Complete Training Cryptocurrency Trading Complete Guide Trading Altcoins Forex Robots Expect Earn 175 PA Forex Robot Included Steps Trading Live Trading Real Account Option Trading Rookies Understand Options Completely Learned Stock Trading and Too Learn Trade Profit Find Trade Winning Stocks Trading Inside Bars Master 1 Easy Pattern Successful Fundamentals Financial Planning Options Trading Calendar Spread Course Trader Dividend Investing Build Portfolio Better Future Learn Accounting Understand Business Consistently Win Trading Stocks 30 Days Beginners Guide Quantopian Futures API Buy Cheap Options Options Trading Pricing Model Excel Crash Course Master Excel Financial Analysis Comprehensive Guide Financial Markets Investing Trading Stock Trading Ninja Complete System Trading Success Hedge Mutual Fund Careers Complete Guide Algorithmic Trading Forex Create Forex Robot Power Modeling Bootcamp Advanced Excel 10 Days Options Trading Basics 3Course Bundle Win 97 Options Trades Consistent Returns Trading Options Forex Strategies Kelly Criterion Larry Williams more Elite Trend Trader Learn Trade Stocks Options Forex Options Trading Introduction Day Trade Stock Options Perfect Options Trading Strategy System Unique Forex Trading Learn Trade Forex Like Banks Learn Trade ProfitTrading Japanese Candlesticks Powerful Options Spread Trading Ratio Spread Finance Job You Explanation 14 Finance Roles Blueprint Successful Stock Trading Trading Beginners Intermediate Level Start Trading Stocks Technical Analysis Learn Set Incubator Hedge Fund StepbyStep VPS Forex Trading Protect Forex Robots Introduction Accounting Language Business Basic Excel Basic Bookkeeping Accounting The Greeks Understand Options Trading Options Consistent Returns Calendar Spreads Create Personal Budget Complete Value Investing Course Proven Approach FOREX Trading Price Action Emini ES Futures Advanced Non Directional Options Trading Forex Trading Advanced F ...

# %%
r.extract_keywords_from_text(join_words)

# %%
print(r.get_ranked_phrases_with_scores())
# Out:
# [(1931668.6688249605, 'angular 2 angular 4 complete aspnet mvc 5 course graphql react complete developers guide create simple photo gallery dropzonejs slick php wordpress hour createmanage website twitter bootstrap 2 beginners bootstrap tutorial essentials basic advanced create engaging website twitter bootstrap 2x javascript basics beginners css tutorial beginners style wordpress templates html5 css3 build modern responsive websites psd html5css3 twitter bootstrap 3 web development website sell thousands wordpress basics business share sell expertise php zend framework 2creating crud application javascript fundamentals building website jekyll big data apache hadoop developers fundamentals wordpress development create custom wordpress website wordpress website 2017 restful services aspnet web api web hosting fundamentals learning path react stunning react websites administering microsoft sql server 2012 databases 70462 php codeignitercrud concepts mvc adobe experience manager cms basics introduction frontend web development beginners php complete login registration system php mysql javascript complete guide learning javascript advanced scalable python web development flask jquery absolute beginners lite html complete course beginner expert crossplatform development aspnet core 10 mvc build photo blog ruby rails practical php master basics code dynamic websites sass workflow learn php fundamentals scratch xml absolute beginners learn create tags joomla create joomla website weekend coding javascript beginners complete guide laravel deployment launch laravel application online wordpress development crash course zero hero learn create wordpress theme pinegrow learn build web apps laravel framework flexbox complete guide safely copy wordpress website angularjs basics beginners json beginners basic introduction learn sass improve css angular tutorial beginners html css absolute beginners javascript jquery ajax laravel blog development starter react learn reactjs fundamentals frontend developers javascript absolute beginners level create real estate website wordpress 2017 complete html5 css3 course 8 websites design introduction modern programming php html introduction course learn html 2 hours learn html css start web development career react vs angular vs vuejs example create wordpress plugins build deploy lamp server aws build beautiful blog wordpress seo angularjs authentication secure app auth0 learn bootstrap 4 example complete woocommerce plugin tutorial wordpress 2017 build wordpress website scratch 2017 docker developers newest version 112 swarm mode angular material quickstart html css beginners build website launch online core web app reference guide django python json java apis jquery json rest web services bootstrap 4 quick start code modern responsive websites learn symfony 3 framework practical examples complete web development html css javascript web hosting introduction publish website online django beginners introduction qgis python programming learning objectoriented javascript bootstrap tutorial beginners learn bootstrap3 multi purposes single page layout html beginners build wordpress themes web designers guide xml dtd basics beginners learn html 5 website video background learn authentication aspnet identity security 2017 html css foundations python web programming build complete registration login system php mvc es6 ecmascript 6 beginners introduction react visual learners learn create advance responsive websites bootstrap master art web design html css sell courses website coding required implementing data warehouse sql server 2012 learning 200 jquery functions 800 examples create complete web applications easily apex 5 learn gulp streaming build system perfect react js course understand relevant details create classified website 2 hours guaranteed learn html css scratch certified web developer beginner expert complete bootstrap 4 course build 3 projects running phalcon html html awesomeness build crud applic ...
